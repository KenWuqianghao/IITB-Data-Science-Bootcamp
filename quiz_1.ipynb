# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Assignment_Solutions/master/Standard%20Metropolitan%20Areas%20Data%20-%20train_data%20-%20data.csv")
df.head()
# Out:
#    land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0       1384          78.1            12.3       25627          69678
# 1       3719          43.9             9.4       13326          43292
# 2       3553          37.4            10.7        9724          33731
# 3       3916          29.9             8.8        6402          24167
# 4       2480          31.5            10.5        8502          16751
#
#    graduates  work_force  income  region  crime_rate
# 0       50.1      4083.9   72100       1       75.55
# 1       53.9      3305.9   54542       2       56.03
# 2       50.6      2066.3   33216       1       41.32
# 3       52.2      1966.7   32906       2       67.38
# 4       66.1      1514.5   26573       4       80.19

# %%
plt.hist(df.income, bins=13)
plt.show()

# %%
df.land_area.mean()
# Out:
# 2615.7272727272725

# %%
df.crime_rate.max()
# Out:
# 85.62

# %%
df.income.min()
# Out:
# 769

# %%
len(df.hospital_beds) - df.hospital_beds.isnull().sum()
# Out:
# 99

# %%
df.region.mode().iat[0]
# Out:
# 3

# %%
len(df[df['region'] == 4])
# Out:
# 17

# %%
df.crime_rate.mean()
# Out:
# 55.6430303030303

# %%
plt.scatter(df.physicians,df.hospital_beds)
plt.show()

# %%
df[df.region == 4].land_area.head()
# Out:
# 4      2480
# 13      782
# 14     4226
# 18    27293
# 20     9155
# Name: land_area, dtype: int64

# %%
plt.hist(df.region, bins=4)
plt.show()

# %%
df.dtypes
# Out:
# land_area           int64
# percent_city      float64
# percent_senior    float64
# physicians          int64
# hospital_beds       int64
# graduates         float64
# work_force        float64
# income              int64
# region              int64
# crime_rate        float64
# dtype: object

# %%
figure = plt.figure(figsize=(12, 6))
sn.heatmap(df.corr(), annot=True,cmap=plt.cm.cool)
plt.tight_layout()
plt.show()

# %%
plt.plot(df.land_area,df.crime_rate)
plt.show()

# %%
len(df[df.region == 1][df[df.region == 1].crime_rate >= 54.16])
# Out:
# 4

# %%
len(df[df.region == 3]) + len(df[df.land_area >= 5000])
# Out:
# 44

# %%
len(df[df.region == 4][df[df.region == 4].crime_rate == 85.62])
# Out:
# 1

# %%
len(df[df.region == 4][df[df.region == 4].crime_rate == 55.64])
# Out:
# 0
